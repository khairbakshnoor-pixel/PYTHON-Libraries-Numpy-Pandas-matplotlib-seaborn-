# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Real estate.csv')
df.head(2)
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2

# %%
df.shape
# Out:
# (414, 8)

# %%
df.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
df.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
df.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3

# %%
df.drop('No', axis=1)
# Out:
#      X1 transaction date  X2 house age  \
# 0               2012.917          32.0
# 1               2012.917          19.5
# 2               2013.583          13.3
# 3               2013.500          13.3
# 4               2012.833           5.0
# ..                   ...           ...
# 409             2013.000          13.7
# 410             2012.667           5.6
# 411             2013.250          18.8
# 412             2013.000           8.1
# 413             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ...

# %%
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
df.drop('No', axis=1, inplace=True)

# %%
df
# Out:
#      X1 transaction date  X2 house age  \
# 0               2012.917          32.0
# 1               2012.917          19.5
# 2               2013.583          13.3
# 3               2013.500          13.3
# 4               2012.833           5.0
# ..                   ...           ...
# 409             2013.000          13.7
# 410             2012.667           5.6
# 411             2013.250          18.8
# 412             2013.000           8.1
# 413             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ...

# %%
df.dtypes
# Out:
# X1 transaction date                       float64
# X2 house age                              float64
# X3 distance to the nearest MRT station    float64
# X4 number of convenience stores             int64
# X5 latitude                               float64
# X6 longitude                              float64
# Y house price of unit area                float64
# dtype: object

# %%
df.rename(columns={
    'X1 transaction date':'Tdate',
    'X2 house age': 'Hage',
    'X3 distance to the nearest MRT station': 'NearestMRT',
    'X4 number of convenience stores': 'NoConv',
    'X5 latitude':'Latitude',
    'X6 longitude': 'Longitude',
    'Y house price of unit area': 'Price'
}, inplace=True)

# %%
df.columns
# Out:
# Index(['Tdate', 'Hage', 'NearestMRT', 'NoConv', 'Latitude', 'Longitude',
#        'Price'],
#       dtype='object')

# %%
sns.histplot(df['Price'])
plt.title('Price Distribution')
plt.xlabel('Price')
plt.show()

# %%
df['Price'].mean()
# Out:
# np.float64(37.980193236714975)

# %%
df['Price'].max()
# Out:
# 117.5

# %%
df['Price'].min()
# Out:
# 7.6

# %%
# 5 houses with age older than 20 yrs
df[df['Hage']>20].head(5)
# Out:
#        Tdate  Hage  NearestMRT  NoConv  Latitude  Longitude  Price
# 0   2012.917  32.0    84.87882      10  24.98298  121.54024   37.9
# 6   2012.667  34.5   623.47310       7  24.97933  121.53642   40.3
# 7   2013.417  20.3   287.60250       6  24.98042  121.54228   46.7
# 8   2013.500  31.7  5512.03800       1  24.95095  121.48458   18.8
# 10  2013.083  34.8   405.21340       1  24.97349  121.53372   41.4

# %%
#5 houses near MRT station (distance < 500)
df[df['NearestMRT']<500].head()
# Out:
#        Tdate  Hage  NearestMRT  NoConv  Latitude  Longitude  Price
# 0   2012.917  32.0    84.87882      10  24.98298  121.54024   37.9
# 1   2012.917  19.5   306.59470       9  24.98034  121.53951   42.2
# 4   2012.833   5.0   390.56840       5  24.97937  121.54245   43.1
# 7   2013.417  20.3   287.60250       6  24.98042  121.54228   46.7
# 10  2013.083  34.8   405.21340       1  24.97349  121.53372   41.4

# %%
#Find the std of price
df.Price.std()
# Out:
# 13.606487697735314

# %%
np.std(df['Price'])
# Out:
# 13.590044806293161

# %%
correlation = df.corr()
correlation['Price'].sort_values(ascending=False)
# Out:
# Price         1.000000
# NoConv        0.571005
# Latitude      0.546307
# Longitude     0.523287
# Tdate         0.087491
# Hage         -0.210567
# NearestMRT   -0.673613
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
a = df.groupby('NoConv')['Price'].mean()
a
# Out:
# NoConv
# 0     26.462687
# 1     31.839130
# 2     31.412500
# 3     29.536957
# 4     37.474194
# 5     44.729851
# 6     46.951351
# 7     43.848387
# 8     44.696667
# 9     51.732000
# 10    48.430000
# Name: Price, dtype: float64

# %%
# Avg price based on the num of convenience stores
a = df.groupby('NoConv')['Price'].mean()
plt.bar(x= a.index,height=a.values)
plt.title('Avg price based on no. of conv stores')
plt.xlabel('No. of Stores')
plt.ylabel('Price')
plt.show()

# %%
#New Feature: Price per store ratio
df['PPSR'] = df['Price'] / (df['NoConv'] + 1)

# %%
df['PPSR']
# Out:
# 0       3.445455
# 1       4.220000
# 2       7.883333
# 3       9.133333
# 4       7.183333
#          ...
# 409    15.400000
# 410     5.000000
# 411     5.075000
# 412     8.750000
# 413     6.390000
# Name: PPSR, Length: 414, dtype: float64

# %%
# Find most expensive house in the dataset
df.sort_values(by='Price', ascending=False).head(3)
# Out:
#         Tdate  Hage  NearestMRT  NoConv  Latitude  Longitude  Price   PPSR
# 270  2013.333  10.8    252.5822       1  24.97460  121.53046  117.5  58.75
# 220  2013.333  37.2    186.5101       9  24.97703  121.54265   78.3   7.83
# 312  2013.583  35.4    318.5292       9  24.97071  121.54069   78.0   7.80

# %%
#count houses with more than 5 conv stores nearby
len(df[df['NoConv'] > 5])
# Out:
# 133

# %%
import datetime

# %%
df['Tdate']
# Out:
# 0      2012.917
# 1      2012.917
# 2      2013.583
# 3      2013.500
# 4      2012.833
#          ...
# 409    2013.000
# 410    2012.667
# 411    2013.250
# 412    2013.000
# 413    2013.500
# Name: Tdate, Length: 414, dtype: float64

# %%
df['Tmonth'] = df['Tdate'].astype(str).str.split('.').str[1].astype(int)

# %%
df[['Tdate','Tmonth']]
# Out:
#         Tdate  Tmonth
# 0    2012.917     917
# 1    2012.917     917
# 2    2013.583     583
# 3    2013.500       5
# 4    2012.833     833
# ..        ...     ...
# 409  2013.000       0
# 410  2012.667     667
# 411  2013.250      25
# 412  2013.000       0
# 413  2013.500       5
#
# [414 rows x 2 columns]

# %%
sns.boxplot(data=df, x='Tmonth',y='Price')
plt.title('Seasonal Trend')
plt.xlabel('Month')
plt.ylabel('Price')
plt.show()

# %%
df.groupby('Tmonth')['Price'].median()
# Out:
# Tmonth
# 0      33.00
# 5      38.20
# 25     41.80
# 75     37.50
# 83     39.85
# 167    40.50
# 333    41.20
# 417    40.05
# 583    36.80
# 667    40.00
# 833    33.40
# 917    36.80
# Name: Price, dtype: float64

# %%
def fractional_year_to_date(fyear):
  year = int(fyear)
  rem = fyear - year
  base = datetime.datetime(year,1,1)
  result_date = base + datetime.timedelta(days=rem*365)
  return result_date

# %%
df['Tdatetime'] = df['Tdate'].apply(fractional_year_to_date)

# %%
df
# Out:
#         Tdate  Hage  NearestMRT  NoConv  Latitude  Longitude  Price  \
# 0    2012.917  32.0    84.87882      10  24.98298  121.54024   37.9
# 1    2012.917  19.5   306.59470       9  24.98034  121.53951   42.2
# 2    2013.583  13.3   561.98450       5  24.98746  121.54391   47.3
# 3    2013.500  13.3   561.98450       5  24.98746  121.54391   54.8
# 4    2012.833   5.0   390.56840       5  24.97937  121.54245   43.1
# ..        ...   ...         ...     ...       ...        ...    ...
# 409  2013.000  13.7  4082.01500       0  24.94155  121.50381   15.4
# 410  2012.667   5.6    90.45606       9  24.97433  121.54310   50.0
# 411  2013.250  18.8   390.96960       7  24.97923  121.53986   40.6
# 412  2013.000   8.1   104.81010       5  24.96674  121.54067   52.5
# 413  2013.500   6.5    90.45606       9  24.97433  121.54310   63.9
#
#           PPSR  Tmonth                  Tdatetime
# 0     3.445455     917 2012-11-30 16:55:11.999997
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tdate       414 non-null    float64
#  1   Hage        414 non-null    float64
#  2   NearestMRT  414 non-null    float64
#  3   NoConv      414 non-null    int64
#  4   Latitude    414 non-null    float64
#  5   Longitude   414 non-null    float64
#  6   Price       414 non-null    float64
#  7   PPSR        414 non-null    float64
#  8   Tmonth      414 non-null    int64
#  9   Tdatetime   414 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), int64(2)
# memory usage: 32.5 KB

# %%
df['TmonthB'] = df['Tdatetime'].dt.month
df
# Out:
#         Tdate  Hage  NearestMRT  NoConv  Latitude  Longitude  Price  \
# 0    2012.917  32.0    84.87882      10  24.98298  121.54024   37.9
# 1    2012.917  19.5   306.59470       9  24.98034  121.53951   42.2
# 2    2013.583  13.3   561.98450       5  24.98746  121.54391   47.3
# 3    2013.500  13.3   561.98450       5  24.98746  121.54391   54.8
# 4    2012.833   5.0   390.56840       5  24.97937  121.54245   43.1
# ..        ...   ...         ...     ...       ...        ...    ...
# 409  2013.000  13.7  4082.01500       0  24.94155  121.50381   15.4
# 410  2012.667   5.6    90.45606       9  24.97433  121.54310   50.0
# 411  2013.250  18.8   390.96960       7  24.97923  121.53986   40.6
# 412  2013.000   8.1   104.81010       5  24.96674  121.54067   52.5
# 413  2013.500   6.5    90.45606       9  24.97433  121.54310   63.9
#
#           PPSR  Tmonth                  Tdatetime  TmonthB
# 0     3.445455     917 2012-11-30 16:55:11.999997       11
# ...

# %%
df['MonthName'] = df['Tdatetime'].dt.strftime('%B')
df
# Out:
#         Tdate  Hage  NearestMRT  NoConv  Latitude  Longitude  Price  \
# 0    2012.917  32.0    84.87882      10  24.98298  121.54024   37.9
# 1    2012.917  19.5   306.59470       9  24.98034  121.53951   42.2
# 2    2013.583  13.3   561.98450       5  24.98746  121.54391   47.3
# 3    2013.500  13.3   561.98450       5  24.98746  121.54391   54.8
# 4    2012.833   5.0   390.56840       5  24.97937  121.54245   43.1
# ..        ...   ...         ...     ...       ...        ...    ...
# 409  2013.000  13.7  4082.01500       0  24.94155  121.50381   15.4
# 410  2012.667   5.6    90.45606       9  24.97433  121.54310   50.0
# 411  2013.250  18.8   390.96960       7  24.97923  121.53986   40.6
# 412  2013.000   8.1   104.81010       5  24.96674  121.54067   52.5
# 413  2013.500   6.5    90.45606       9  24.97433  121.54310   63.9
#
#           PPSR  Tmonth                  Tdatetime  TmonthB MonthName
# 0     3.445455     917 2012-11-30 16:55:11.999997       11  November
# ...
