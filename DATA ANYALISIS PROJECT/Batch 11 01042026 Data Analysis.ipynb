# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df2 = pd.read_excel('employees.xlsx')
df2.head(2)
# Out:
#    Serial  Emp_ID Designation Department   Age    Salary
# 0       1    1101     Manager   Accounts  50.0  200000.0
# 1       2    1107     Officer         IT  30.0   80000.0

# %%
sns.boxplot(y=df.Salary)
plt.show()

# %%
#find the outliers in age
# Q1, Q3, IQR, UF, LF

Q1 = df['Age'].quantile(0.25)
Q3 = df['Age'].quantile(0.75)
IQR = Q3-Q1
lf = Q1 - (1.5 * IQR)
uf = Q3 + (1.5 * IQR)

outliers = df[(df['Age'] < lf) | (df['Age'] > uf)]
outliers
# Out:
# Empty DataFrame
# Columns: [Serial, Emp_ID, Designation, Department, Age, Salary]
# Index: []

# %%
Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)
IQR = Q3-Q1
lf = Q1 - (1.5 * IQR)
uf = Q3 + (1.5 * IQR)

outliers = df[(df['Salary'] < lf) | (df['Salary'] > uf)]
outliers
# Out:
#     Serial  Emp_ID Designation Department   Age    Salary
# 0        1    1101     Manager   Accounts  50.0  200000.0
# 4        5    2123  Office Boy   Accounts  27.0   45000.0
# 17      18    2123  Office Boy   Accounts  27.0   45000.0

# %%
sns.boxplot(df.Salary)
# Out:
# <Axes: ylabel='Salary'>

# %%
#BIVARIATE Analysis (When we study two features together)

# Covariance
# Correlation
# Regression
# Heat map

# %%
import numpy as np
hours = [2,4,6,8]
score = [50,60,70,80]
covar = np.cov(hours,score)
covar
# Out:
# array([[  6.66666667,  33.33333333],
#        [ 33.33333333, 166.66666667]])

# %%
corr = np.corrcoef(hours,score)
corr
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
data = {
    'hours':[2,4,6,8],
    'sleep':[7,6,5,4],
    'score':[50,60,70,80]
}
df=pd.DataFrame(data)
df
# Out:
#    hours  sleep  score
# 0      2      7     50
# 1      4      6     60
# 2      6      5     70
# 3      8      4     80

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
freq = df2.Department.value_counts()
freq
# Out:
# Department
# IT            5
# Accounts      4
# Production    4
# HR            2
# Account       1
# Name: count, dtype: int64

# %%
plt.bar(x=freq.index, height=freq.values, width=0.4)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.pie(x=freq.values, labels=freq.index, autopct='%1.1f%%')
plt.show()

# %%
sns.boxplot(data=df2, x='Designation', y='Salary')
# Out:
# <Axes: xlabel='Designation', ylabel='Salary'>

# %%
sns.boxplot(data=df2, x='Department', y='Salary')
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
df2[(df2.Department=='IT') & (df2.Age>=30)]
# Out:
#     Serial  Emp_ID Designation Department   Age   Salary
# 1        2    1107     Officer         IT  30.0  80000.0
# 14      15    2912     Officer         IT  31.0  90000.0
