# %%
names = ['Ali','Sara','Ahmed']
ages = [20,22,19]
marks = [85,90,78]

# %%
import pandas as pd
s = pd.Series([85,90,78], index=['Ali','Sara','Ahmed'])
t = pd.Series([80,90,95])

# %%
s
# Out:
# Ali      85
# Sara     90
# Ahmed    78
# dtype: int64

# %%
t
# Out:
# 0    80
# 1    90
# 2    95
# dtype: int64

# %%
df = pd.DataFrame({
    'Name': ['Ali','Sara','Ahmed'],
    'Age': [22,25,19],
    'Marks': [85,90,78]
})

# %%
df
# Out:
#     Name  Age  Marks
# 0    Ali   22     85
# 1   Sara   25     90
# 2  Ahmed   19     78

# %%
df['Marks']
# Out:
# 0    85
# 1    90
# 2    78
# Name: Marks, dtype: int64

# %%
df[df['Marks']>=80]
# Out:
#    Name  Age  Marks
# 0   Ali   22     85
# 1  Sara   25     90

# %%
df = pd.read_csv('silver_prices_historical.csv')

# %%
df
# Out:
#             Date  Adj Close      Close       High        Low       Open  \
# 0     2016-01-04  13.817000  13.817000  14.100000  13.817000  14.100000
# 1     2016-01-05  13.949000  13.949000  13.949000  13.949000  13.949000
# 2     2016-01-06  13.957000  13.957000  14.065000  13.957000  14.000000
# 3     2016-01-07  14.335000  14.335000  14.340000  14.330000  14.335000
# 4     2016-01-08  13.908000  13.908000  14.060000  13.908000  14.060000
# ...          ...        ...        ...        ...        ...        ...
# 2519  2026-01-12  84.610001  84.610001  85.824997  82.000000  82.000000
# 2520  2026-01-13  85.876999  85.876999  88.610001  84.589996  84.904999
# 2521  2026-01-14  90.869003  90.869003  93.000000  88.705002  89.349998
# 2522  2026-01-15  91.875999  91.875999  92.419998  86.129997  90.824997
# 2523  2026-01-16  88.091003  88.091003  90.925003  86.195000  90.440002
#
#       Volume     MA_50     MA_200  Daily_Return  Year  Month  Volatility_30d
# ...

# %%
#Pandas is a library for working with labelled, tabular data
# Series = one column
# DataFrame= full table

# %%
students = pd.DataFrame({
    'Student':['Ayesha','Bilal','Usman'],
    'Math':[78,85,90],
    'Science':[82,88,91]
})

# %%
#print the dataframe
#identify rows and columns
students
# Out:
#   Student  Math  Science
# 0  Ayesha    78       82
# 1   Bilal    85       88
# 2   Usman    90       91

# %%
#print only the names
students['Student']
# Out:
# 0    Ayesha
# 1     Bilal
# 2     Usman
# Name: Student, dtype: object

# %%
#print only the first row
students.loc[0]
# Out:
# Student    Ayesha
# Math           78
# Science        82
# Name: 0, dtype: object

# %%
print(students[['Student','Math']])
# Out:
#   Student  Math
# 0  Ayesha    78
# 1   Bilal    85
# 2   Usman    90

# %%
#filter students scoring >85 in maths

# %%
#filter students scoring >80 in science

# %%
#students with maths <80

# %%
df
# Out:
#             Date  Adj Close      Close       High        Low       Open  \
# 0     2016-01-04  13.817000  13.817000  14.100000  13.817000  14.100000
# 1     2016-01-05  13.949000  13.949000  13.949000  13.949000  13.949000
# 2     2016-01-06  13.957000  13.957000  14.065000  13.957000  14.000000
# 3     2016-01-07  14.335000  14.335000  14.340000  14.330000  14.335000
# 4     2016-01-08  13.908000  13.908000  14.060000  13.908000  14.060000
# ...          ...        ...        ...        ...        ...        ...
# 2519  2026-01-12  84.610001  84.610001  85.824997  82.000000  82.000000
# 2520  2026-01-13  85.876999  85.876999  88.610001  84.589996  84.904999
# 2521  2026-01-14  90.869003  90.869003  93.000000  88.705002  89.349998
# 2522  2026-01-15  91.875999  91.875999  92.419998  86.129997  90.824997
# 2523  2026-01-16  88.091003  88.091003  90.925003  86.195000  90.440002
#
#       Volume     MA_50     MA_200  Daily_Return  Year  Month  Volatility_30d
# ...

# %%
df.head() #to show the top 5 records
# Out:
#          Date  Adj Close   Close    High     Low    Open  Volume  MA_50  \
# 0  2016-01-04     13.817  13.817  14.100  13.817  14.100      27    NaN
# 1  2016-01-05     13.949  13.949  13.949  13.949  13.949       4    NaN
# 2  2016-01-06     13.957  13.957  14.065  13.957  14.000     105    NaN
# 3  2016-01-07     14.335  14.335  14.340  14.330  14.335     286    NaN
# 4  2016-01-08     13.908  13.908  14.060  13.908  14.060       6    NaN
#
#    MA_200  Daily_Return  Year  Month  Volatility_30d
# 0     NaN           NaN  2016      1             NaN
# 1     NaN      0.955345  2016      1             NaN
# 2     NaN      0.057348  2016      1             NaN
# 3     NaN      2.708320  2016      1             NaN
# 4     NaN     -2.978724  2016      1             NaN

# %%
df.head(2) #to display top 2 records
# Out:
#          Date  Adj Close   Close    High     Low    Open  Volume  MA_50  \
# 0  2016-01-04     13.817  13.817  14.100  13.817  14.100      27    NaN
# 1  2016-01-05     13.949  13.949  13.949  13.949  13.949       4    NaN
#
#    MA_200  Daily_Return  Year  Month  Volatility_30d
# 0     NaN           NaN  2016      1             NaN
# 1     NaN      0.955345  2016      1             NaN

# %%
df.tail() #for bottom 5 records
# Out:
#             Date  Adj Close      Close       High        Low       Open  \
# 2519  2026-01-12  84.610001  84.610001  85.824997  82.000000  82.000000
# 2520  2026-01-13  85.876999  85.876999  88.610001  84.589996  84.904999
# 2521  2026-01-14  90.869003  90.869003  93.000000  88.705002  89.349998
# 2522  2026-01-15  91.875999  91.875999  92.419998  86.129997  90.824997
# 2523  2026-01-16  88.091003  88.091003  90.925003  86.195000  90.440002
#
#       Volume     MA_50     MA_200  Daily_Return  Year  Month  Volatility_30d
# 2519     575  60.35742  43.764615      7.258757  2026      1       76.402098
# 2520     341  61.10640  44.020780      1.497457  2026      1       74.927540
# 2521     470  61.96390  44.302840      5.812970  2026      1       75.756402
# 2522     390  62.84366  44.591430      1.108184  2026      1       75.449192
# 2523     390  63.66288  44.859390     -4.119679  2026      1       77.140974

# %%
df.tail(2)
# Out:
#             Date  Adj Close      Close       High        Low       Open  \
# 2522  2026-01-15  91.875999  91.875999  92.419998  86.129997  90.824997
# 2523  2026-01-16  88.091003  88.091003  90.925003  86.195000  90.440002
#
#       Volume     MA_50    MA_200  Daily_Return  Year  Month  Volatility_30d
# 2522     390  62.84366  44.59143      1.108184  2026      1       75.449192
# 2523     390  63.66288  44.85939     -4.119679  2026      1       77.140974

# %%
df.shape
# Out:
# (2524, 13)

# %%
df.columns
# Out:
# Index(['Date', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'MA_50',
#        'MA_200', 'Daily_Return', 'Year', 'Month', 'Volatility_30d'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2524 entries, 0 to 2523
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            2524 non-null   object
#  1   Adj Close       2524 non-null   float64
#  2   Close           2524 non-null   float64
#  3   High            2524 non-null   float64
#  4   Low             2524 non-null   float64
#  5   Open            2524 non-null   float64
#  6   Volume          2524 non-null   int64
#  7   MA_50           2475 non-null   float64
#  8   MA_200          2325 non-null   float64
#  9   Daily_Return    2523 non-null   float64
#  10  Year            2524 non-null   int64
#  11  Month           2524 non-null   int64
#  12  Volatility_30d  2494 non-null   float64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 256.5+ KB

# %%
df.isnull().sum()
# Out:
# Date                0
# Adj Close           0
# Close               0
# High                0
# Low                 0
# Open                0
# Volume              0
# MA_50              49
# MA_200            199
# Daily_Return        1
# Year                0
# Month               0
# Volatility_30d     30
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
