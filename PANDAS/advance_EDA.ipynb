# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import  seaborn as sns

# %%
df=pd.read_csv("advanced_eda_practice_dataset.csv")

# %%
df.head()
# Out:
#    Employee_ID  Age  Gender Department Education_Level  Experience_Years  \
# 0         1001   49  Female         IT          Master                18
# 1         1002   35    Male    Finance          Master                10
# 2         1003   28  Female  Marketing             PhD                 4
# 3         1004   41  Female         IT             PhD                11
# 4         1005   39    Male         IT             PhD                 2
#
#      Salary  Performance_Score  Work_Hours_Per_Week Remote_Work  \
# 0  116188.0               2.82                   47         Yes
# 1   34748.0               2.62                   40          No
# 2  116769.0                NaN                   39          No
# 3   39435.0               4.27                   59          No
# 4   33709.0               2.14                   35         Yes
#
#    Job_Satisfaction Promotion_Last_2_Years Attrition Joining_Date
# 0              4.73                     No       Yes   2015-01-31
# ...

# %%
df.tail()
# Out:
#      Employee_ID  Age  Gender Department Education_Level  Experience_Years  \
# 118         1119   40    Male  Marketing        Bachelor                 6
# 119         1120   50  Female         IT        Bachelor                 2
# 120         1006   43  Female         HR          Master                 0
# 121         1007   31    Male         HR          Master                 0
# 122         1008   31    Male    Finance             PhD                 7
#
#       Salary  Performance_Score  Work_Hours_Per_Week Remote_Work  \
# 118  64816.0               3.82                   47          No
# 119  75106.0               2.73                   44         Yes
# 120  60355.0               2.81                   55          No
# 121  85771.0               2.07                   56          No
# 122  87799.0               3.49                   55          No
#
#      Job_Satisfaction Promotion_Last_2_Years Attrition Joining_Date
# ...

# %%
df.isnull().sum()
# Out:
# Employee_ID               0
# Age                       0
# Gender                    0
# Department                0
# Education_Level           0
# Experience_Years          0
# Salary                    5
# Performance_Score         5
# Work_Hours_Per_Week       0
# Remote_Work               0
# Job_Satisfaction          5
# Promotion_Last_2_Years    0
# Attrition                 0
# Joining_Date              0
# dtype: int64

# %%
df['Salary']=df['Salary'].fillna(df['Salary'].median())

# %%
df['Performance_Score']=df['Performance_Score'].fillna(df['Performance_Score'].median())

# %%
df.isnull().sum()
# Out:
# Employee_ID               0
# Age                       0
# Gender                    0
# Department                0
# Education_Level           0
# Experience_Years          0
# Salary                    0
# Performance_Score         0
# Work_Hours_Per_Week       0
# Remote_Work               0
# Job_Satisfaction          5
# Promotion_Last_2_Years    0
# Attrition                 0
# Joining_Date              0
# dtype: int64

# %%
df['Job_Satisfaction']=df['Job_Satisfaction'].fillna(df['Job_Satisfaction'].median())

# %%
df.isnull().sum()
# Out:
# Employee_ID               0
# Age                       0
# Gender                    0
# Department                0
# Education_Level           0
# Experience_Years          0
# Salary                    0
# Performance_Score         0
# Work_Hours_Per_Week       0
# Remote_Work               0
# Job_Satisfaction          0
# Promotion_Last_2_Years    0
# Attrition                 0
# Joining_Date              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(3)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120 entries, 0 to 119
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Employee_ID             120 non-null    int64
#  1   Age                     120 non-null    int64
#  2   Gender                  120 non-null    object
#  3   Department              120 non-null    object
#  4   Education_Level         120 non-null    object
#  5   Experience_Years        120 non-null    int64
#  6   Salary                  120 non-null    float64
#  7   Performance_Score       120 non-null    float64
#  8   Work_Hours_Per_Week     120 non-null    int64
#  9   Remote_Work             120 non-null    object
#  10  Job_Satisfaction        120 non-null    float64
#  11  Promotion_Last_2_Years  120 non-null    object
#  12  Attrition               120 non-null    object
#  13  Joining_Date            120 non-null    object
# ...

# %%
df['Joining_Date']=pd.to_datetime(df['Joining_Date'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120 entries, 0 to 119
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Employee_ID             120 non-null    int64
#  1   Age                     120 non-null    int64
#  2   Gender                  120 non-null    object
#  3   Department              120 non-null    object
#  4   Education_Level         120 non-null    object
#  5   Experience_Years        120 non-null    int64
#  6   Salary                  120 non-null    float64
#  7   Performance_Score       120 non-null    float64
#  8   Work_Hours_Per_Week     120 non-null    int64
#  9   Remote_Work             120 non-null    object
#  10  Job_Satisfaction        120 non-null    float64
#  11  Promotion_Last_2_Years  120 non-null    object
#  12  Attrition               120 non-null    object
#  13  Joining_Date            120 non-null    datetime64[ns]
# ...

# %%
df['Joining_Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['joing_year']=df['Joining_Date'].dt.year

# %%
df['joing_month']=df['Joining_Date'].dt.month

# %%
df
# Out:
#      Employee_ID  Age  Gender Department Education_Level  Experience_Years  \
# 0           1001   49  Female         IT          Master                18
# 1           1002   35    Male    Finance          Master                10
# 2           1003   28  Female  Marketing             PhD                 4
# 3           1004   41  Female         IT             PhD                11
# 4           1005   39    Male         IT             PhD                 2
# ..           ...  ...     ...        ...             ...               ...
# 115         1116   26    Male         IT             PhD                 6
# 116         1117   48  Female  Marketing          Master                 9
# 117         1118   48  Female      Sales             PhD                18
# 118         1119   40    Male  Marketing        Bachelor                 6
# 119         1120   50  Female         IT        Bachelor                 2
#
#        Salary  Performance_Score  Work_Hours_Per_Week Remote_Work  \
# ...

# %%
df.shape
# Out:
# (120, 16)

# %%
df.describe()
# Out:
#        Employee_ID         Age  Experience_Years        Salary  \
# count   120.000000  120.000000        120.000000     120.00000
# mean   1060.500000   37.175000          9.708333   69622.28750
# min    1001.000000   21.000000          0.000000   30384.00000
# 25%    1030.750000   28.000000          5.000000   51225.00000
# 50%    1060.500000   37.000000         10.000000   67143.50000
# 75%    1090.250000   45.250000         15.000000   87232.00000
# max    1120.000000   54.000000         19.000000  116769.00000
# std      34.785054    9.714982          5.563077   23851.06881
#
#        Performance_Score  Work_Hours_Per_Week  Job_Satisfaction  \
# count         120.000000            120.00000        120.000000
# mean            3.487667             45.77500          2.868500
# min             2.010000             35.00000          1.020000
# 25%             2.950000             39.00000          1.877500
# 50%             3.560000             45.00000          2.780000
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(df['Salary'])
# Out:
# (array([13., 10., 18., 15., 15.,  9., 13., 11.,  6., 10.]),
#  array([ 30384. ,  39022.5,  47661. ,  56299.5,  64938. ,  73576.5,
#          82215. ,  90853.5,  99492. , 108130.5, 116769. ]),
#  <BarContainer object of 10 artists>)

# %%
df["Department"].value_counts()
df["Attrition"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Attrition'>

# %%
plt.scatter(df["Experience_Years"], df["Salary"])
df[["Experience_Years","Salary"]].corr()
# Out:
#                   Experience_Years    Salary
# Experience_Years          1.000000  0.107628
# Salary                    0.107628  1.000000

# %%
df.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance      61585.080000
# HR           70221.175000
# IT           71664.296875
# Marketing    71744.895833
# Sales        73446.789474
# Name: Salary, dtype: float64

# %%
df.groupby("Gender")['Salary'].mean()
# Out:
# Gender
# Female    72234.508333
# Male      67010.066667
# Name: Salary, dtype: float64

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Education_Level',
#        'Experience_Years', 'Salary', 'Performance_Score',
#        'Work_Hours_Per_Week', 'Remote_Work', 'Job_Satisfaction',
#        'Promotion_Last_2_Years', 'Attrition', 'Joining_Date', 'joing_year',
#        'joing_month'],
#       dtype='object')

# %%
df.groupby("Experience_Years")['Salary'].mean().sort_values(ascending=False)
# Out:
# Experience_Years
# 19    83005.750000
# 12    82659.750000
# 13    81709.500000
# 18    79637.444444
# 1     79414.666667
# 8     78579.285714
# 15    76823.600000
# 4     76118.642857
# 6     71683.444444
# 11    69238.100000
# 9     68013.571429
# 7     67229.375000
# 17    66205.500000
# 3     62703.250000
# 0     61995.333333
# 2     59443.000000
# 16    58377.000000
# 10    52955.600000
# 5     49901.666667
# 14    47973.500000
# Name: Salary, dtype: float64

# %%
df.groupby('Work_Hours_Per_Week')['Salary'].mean().sort_index(ascending=False)
# Out:
# Work_Hours_Per_Week
# 59    63645.333333
# 58    80100.833333
# 57    78815.200000
# 56    82889.000000
# 55    59271.750000
# 54    62950.625000
# 53    65275.200000
# 52    70444.500000
# 51    72772.000000
# 50    72918.000000
# 49    66260.000000
# 48    45549.750000
# 47    94138.400000
# 46    73546.700000
# 45    73769.625000
# 44    70386.333333
# 43    59152.600000
# 42    64936.500000
# 40    50350.600000
# 39    74016.600000
# 38    78741.583333
# 37    67683.833333
# 36    74728.400000
# 35    72341.416667
# Name: Salary, dtype: float64

# %%
df.groupby('Remote_Work')['Salary'].mean().sort_index(ascending=False)
# Out:
# Remote_Work
# Yes    69851.195312
# No     69360.678571
# Name: Salary, dtype: float64

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Education_Level',
#        'Experience_Years', 'Salary', 'Performance_Score',
#        'Work_Hours_Per_Week', 'Remote_Work', 'Job_Satisfaction',
#        'Promotion_Last_2_Years', 'Attrition', 'Joining_Date', 'joing_year',
#        'joing_month'],
#       dtype='object')

# %%
df.groupby('Performance_Score')['Salary'].mean().sort_index(ascending=False)
# Out:
# Performance_Score
# 4.96    31015.0
# 4.94    52700.0
# 4.92    34835.0
# 4.90    82224.0
# 4.77    57712.0
#          ...
# 2.14    44106.5
# 2.10    87043.0
# 2.09    50384.0
# 2.07    85771.0
# 2.01    88141.0
# Name: Salary, Length: 98, dtype: float64

# %%
df.groupby('Attrition')['Salary'].mean().sort_index(ascending=False)
# Out:
# Attrition
# Yes    69234.90
# No     70164.63
# Name: Salary, dtype: float64

# %%
df.groupby('Department')['Salary'].mean().sort_index(ascending=False)
# Out:
# Department
# Sales        73446.789474
# Marketing    71744.895833
# IT           71664.296875
# HR           70221.175000
# Finance      61585.080000
# Name: Salary, dtype: float64

# %%
ax=df['Department'].value_counts()

# %%
plt.hist(x=df['Department'])
# Out:
# (array([32.,  0., 25.,  0.,  0., 24.,  0., 20.,  0., 19.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Salary'])
plt.show()

# %%
plt.scatter(df['Experience_Years'], df['Salary'])
plt.show()

# %%
sns.boxplot(x='Department', y='Salary', data=df)
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
sns.countplot(x='Attrition', hue='Department', data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
sns.barplot(x='Department', y='Salary', data=df)
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
sns.barplot(x='Experience_Years', y='Salary', data=df)
# Out:
# <Axes: xlabel='Experience_Years', ylabel='Salary'>

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Education_Level',
#        'Experience_Years', 'Salary', 'Performance_Score',
#        'Work_Hours_Per_Week', 'Remote_Work', 'Job_Satisfaction',
#        'Promotion_Last_2_Years', 'Attrition', 'Joining_Date', 'joing_year',
#        'joing_month'],
#       dtype='object')

# %%
sns.lineplot(x=df['Joining_Date'],y=df['Salary'])
# Out:
# <Axes: xlabel='Joining_Date', ylabel='Salary'>

# %%
plt.hist(df['Salary'], bins=10, color='skyblue', edgecolor='black')
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.show()

# %%
# Boxplot for outliers
sns.boxplot(y='Salary', data=df)
plt.title("Salary Outliers")
plt.show()

# %%
# Count of categories
df['Department'].value_counts().plot(kind='bar', color='orange')
plt.title("Department Count")
plt.ylabel("Number of Employees")
plt.show()

# Using seaborn
sns.countplot(x='Attrition', data=df)
plt.title("Attrition Count")
plt.show()

# %%
plt.scatter(df['Experience_Years'], df['Salary'])
plt.xlabel("Experience (Years)")
plt.ylabel("Salary")
plt.title("Experience vs Salary")
plt.show()

# %%
sns.boxplot(x='Department', y='Salary', data=df)
plt.title("Salary by Department")
plt.show()

# %%
sns.countplot(x='Attrition', hue='Department', data=df)
plt.title("Attrition by Department")
plt.show()
