# %%
# Out:
# '\nclass vs instance variables\nmagic / dunder methods\ntight coupling and loose coupling\n'

# %%
sales = [12000, 15000, 11000, 10000, 17000]
total = 0
for s in sales:
  total += s
average = total / len(sales)
print(total, average)
# Out:
# 65000 13000.0

# %%
taxed_sale = []
for s in sales:
  taxed_sale.append(s * 1.10)
print(taxed_sale)
# Out:
# [13200.000000000002, 16500.0, 12100.000000000002, 11000.0, 18700.0]

# %%
sales * 1.10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4206743426.py in <cell line: 0>()
# ----> 1 sales * 1.10
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
[12000,15000] * 2
# Out:
# [12000, 15000, 12000, 15000]

# %%
sales_2024 = [12000, 15000, 11000]
sales_2025 = [13000, 16000, 15000]

# %%
import numpy as np
sales = np.array([12000, 15000, 11000, 10000, 17000])

# %%
sales
# Out:
# array([12000, 15000, 11000, 10000, 17000])

# %%
sales * 1.1
# Out:
# array([13200., 16500., 12100., 11000., 18700.])

# %%
sales * 2
# Out:
# array([24000, 30000, 22000, 20000, 34000])

# %%
sales
# Out:
# array([12000, 15000, 11000, 10000, 17000])

# %%
a = sales * 1.1
a
# Out:
# array([13200., 16500., 12100., 11000., 18700.])

# %%
a
# Out:
# array([13200., 16500., 12100., 11000., 18700.])

# %%
sales_2024 = np.array([12000, 15000, 11000])
sales_2025 = np.array([13000, 16000, 15000])

sales_2025-sales_2024
# Out:
# array([1000, 1000, 4000])

# %% [markdown]
# convert a list of temperatures to numpy
#
# increase all the values by 5% and save in a new array
#
# subtract two numpy arrays

# %%
arr1 = np.array([36,55,24,29,41])

# %%
arr2 = arr1 * 1.05
arr2
# Out:
# array([37.8 , 57.75, 25.2 , 30.45, 43.05])

# %%
arr2 - arr1
# Out:
# array([1.8 , 2.75, 1.2 , 1.45, 2.05])

# %%
a = np.array([1,2,3,4])
b = np.array([1,6,3.3,5.2])

# %%
a.dtype
# Out:
# dtype('int64')

# %%
b.dtype
# Out:
# dtype('float64')

# %%
b
# Out:
# array([1. , 6. , 3.3, 5.2])

# %%
c = np.array([True, 'a', 1, 2.2])
c.dtype
c
# Out:
# array(['True', 'a', '1', '2.2'], dtype='<U32')

# %%
a = np.array([1,2,3,4])
a.shape
# Out:
# (4,)

# %%
a = np.array([[1,2,3,4],
              [5,6,7,8]])
a.shape
# Out:
# (2, 4)

# %%
a.ndim
# Out:
# 2

# %%
a.size
# Out:
# 8

# %%
data = np.array([
    [5,10,15],
    [20,25,30],
    [35,40,45]])
    #find shape, size, dimensions

# %%
#from array (data) find 25 using slicing
print(data[1][1])
# Out:
# 25

# %%
#from array (data) extract 3rd row using slicing
data[2]
# Out:
# array([35, 40, 45])

# %%
arr = np.array([10,20,30])
print(arr+5)
print(arr-3)
print(arr**2)
# Out:
# [15 25 35]
# [ 7 17 27]
# [100 400 900]

# %%
arr2 = np.array([1,2,3])

# %%
a + b
# Out:
# array([[ 2. ,  8. ,  6.3,  9.2],
#        [ 6. , 12. , 10.3, 13.2]])
